# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/childes_parsing/
# Out:
# /content/drive/MyDrive/childes_parsing

# %%
import io, os

### Read *.conllu file ###

def conll_read_sentence(file_handle):
	sent = []
	for line in file_handle:
		line = line.strip('\n')	
		if line.startswith('#') is False :
			toks = line.split("\t")					
			if len(toks) == 1:
				return sent 
			else:
				if toks[0].isdigit() == True:
					sent.append(toks)
	return None


for child in ['Abe_Kuczaj', 'Adam_Brown', 'Emma_Weist', 'Laura_Braunwald', 'Lily_Providence', 'Naima_Providence', 'Roman_Weist', 'Sarah_Brown', 'Thomas_Thomas', 'Violet_Providence']:
	train = []
	for directory in os.listdir('processed_data/'):
		for file in os.listdir('processed_data/' + directory + '/'):
			if file.endswith('parent'):
				with open('processed_data/' + directory + '/' + file) as f:
					sent = conll_read_sentence(f)
					while sent is not None:
						train.append(sent)
						sent = conll_read_sentence(f)
	
	with open('processed_data/' + child + '/train_parents.conllu', 'w') as f:
		for sent in train:
			for tok in sent:
				f.write('\t'.join(w for w in tok) + '\n')
			f.write('\n')

# %%
# !git clone https://github.com/Unipisa/diaparser
# Out:
# Cloning into 'diaparser'...
# remote: Enumerating objects: 787, done.
# remote: Counting objects: 100% (96/96), done.
# remote: Compressing objects: 100% (57/57), done.
# remote: Total 787 (delta 42), reused 88 (delta 37), pack-reused 691
# Receiving objects: 100% (787/787), 232.81 KiB | 3.15 MiB/s, done.
# Resolving deltas: 100% (455/455), done.

# %%
# %cd diaparser
# !python setup.py install

# %%
# !python -m diaparser.cmds.biaffine_dependency train  \
    --train ../UD_data/UD_English-GUMReddit/en_gumreddit-ud-train.conllu \
    --dev  ../UD_data/UD_English-GUMReddit/en_gumreddit-ud-dev.conllu \
    --test ../UD_data/UD_English-GUMReddit/en_gumreddit-ud-test.conllu \
    -b -d 0  \
    -p logs/diaparser.reddit.1.bert-base-cased  \
    -f bert  \
    --bert bert-base-cased  \
    -s 1
# Out:
# 2022-08-01 20:35:34 INFO Configuration:
# ---------------------+--------------------------
# Param                |           Value
# ---------------------+--------------------------
# tree                 |           False
# proj                 |           False
# partial              |           False
# mode                 |           train
# path                 | logs/diaparser.reddit.1.bert-base-cased
# device               |             0
# seed                 |             1
# threads              |            16
# batch_size           |           5000
# local_rank           |            -1
# verbose              |           True
# Parser               | <class 'diaparser.parsers.biaffine_dependency.BiaffineDependencyParser'>
# feat                 |           bert
# build                |           True
# punct                |           False
# max_len              |           None
# buckets              |            32
# ...

# %%
# !python -m diaparser.cmds.biaffine_dependency train  \
    --train ../UD_data/UD_English-GUMReddit/en_gumreddit-ud-train.conllu \
    --dev  ../UD_data/UD_English-GUMReddit/en_gumreddit-ud-dev.conllu \
    --test ../UD_data/UD_English-GUMReddit/en_gumreddit-ud-test.conllu \
    -b -d 0  \
    -p logs/diaparser.reddit.2.bert-base-cased  \
    -f bert  \
    --bert bert-base-cased  \
    -s 2
# Out:
# 2022-08-01 20:44:30 INFO Configuration:
# ---------------------+--------------------------
# Param                |           Value
# ---------------------+--------------------------
# tree                 |           False
# proj                 |           False
# partial              |           False
# mode                 |           train
# path                 | logs/diaparser.reddit.2.bert-base-cased
# device               |             0
# seed                 |             2
# threads              |            16
# batch_size           |           5000
# local_rank           |            -1
# verbose              |           True
# Parser               | <class 'diaparser.parsers.biaffine_dependency.BiaffineDependencyParser'>
# feat                 |           bert
# build                |           True
# punct                |           False
# max_len              |           None
# buckets              |            32
# ...

# %%
# !python -m diaparser.cmds.biaffine_dependency train  \
    --train ../UD_data/UD_English-GUMReddit/en_gumreddit-ud-train.conllu \
    --dev  ../UD_data/UD_English-GUMReddit/en_gumreddit-ud-dev.conllu \
    --test ../UD_data/UD_English-GUMReddit/en_gumreddit-ud-test.conllu \
    -b -d 0  \
    -p logs/diaparser.reddit.3.bert-base-cased  \
    -f bert  \
    --bert bert-base-cased  \
    -s 3
# Out:
# 2022-08-01 20:53:01 INFO Configuration:
# ---------------------+--------------------------
# Param                |           Value
# ---------------------+--------------------------
# tree                 |           False
# proj                 |           False
# partial              |           False
# mode                 |           train
# path                 | logs/diaparser.reddit.3.bert-base-cased
# device               |             0
# seed                 |             3
# threads              |            16
# batch_size           |           5000
# local_rank           |            -1
# verbose              |           True
# Parser               | <class 'diaparser.parsers.biaffine_dependency.BiaffineDependencyParser'>
# feat                 |           bert
# build                |           True
# punct                |           False
# max_len              |           None
# buckets              |            32
# ...

# %%
# !python -m diaparser.cmds.biaffine_dependency train  \
    --train ../UD_data/UD_English-GUMReddit/en_gumreddit-ud-train.conllu \
    --dev  ../UD_data/UD_English-GUMReddit/en_gumreddit-ud-dev.conllu \
    --test ../UD_data/UD_English-GUMReddit/en_gumreddit-ud-test.conllu \
    -b -d 0  \
    -p logs/diaparser.reddit.1.roberta-base  \
    -f bert  \
    --bert roberta-base  \
    -s 1
# Out:
# 2022-08-01 21:01:13 INFO Configuration:
# ---------------------+--------------------------
# Param                |           Value
# ---------------------+--------------------------
# tree                 |           False
# proj                 |           False
# partial              |           False
# mode                 |           train
# path                 | logs/diaparser.reddit.1.roberta-base
# device               |             0
# seed                 |             1
# threads              |            16
# batch_size           |           5000
# local_rank           |            -1
# verbose              |           True
# Parser               | <class 'diaparser.parsers.biaffine_dependency.BiaffineDependencyParser'>
# feat                 |           bert
# build                |           True
# punct                |           False
# max_len              |           None
# buckets              |            32
# ...

# %%
# !python -m diaparser.cmds.biaffine_dependency train  \
    --train ../UD_data/UD_English-GUMReddit/en_gumreddit-ud-train.conllu \
    --dev  ../UD_data/UD_English-GUMReddit/en_gumreddit-ud-dev.conllu \
    --test ../UD_data/UD_English-GUMReddit/en_gumreddit-ud-test.conllu \
    -b -d 0  \
    -p logs/diaparser.reddit.2.roberta-base  \
    -f bert  \
    --bert roberta-base  \
    -s 2
# Out:
# 2022-08-01 21:09:37 INFO Configuration:
# ---------------------+--------------------------
# Param                |           Value
# ---------------------+--------------------------
# tree                 |           False
# proj                 |           False
# partial              |           False
# mode                 |           train
# path                 | logs/diaparser.reddit.2.roberta-base
# device               |             0
# seed                 |             2
# threads              |            16
# batch_size           |           5000
# local_rank           |            -1
# verbose              |           True
# Parser               | <class 'diaparser.parsers.biaffine_dependency.BiaffineDependencyParser'>
# feat                 |           bert
# build                |           True
# punct                |           False
# max_len              |           None
# buckets              |            32
# ...

# %%
# !python -m diaparser.cmds.biaffine_dependency train  \
    --train ../UD_data/UD_English-GUMReddit/en_gumreddit-ud-train.conllu \
    --dev  ../UD_data/UD_English-GUMReddit/en_gumreddit-ud-dev.conllu \
    --test ../UD_data/UD_English-GUMReddit/en_gumreddit-ud-test.conllu \
    -b -d 0  \
    -p logs/diaparser.reddit.3.roberta-base  \
    -f bert  \
    --bert roberta-base  \
    -s 3
# Out:
# 2022-08-01 21:18:11 INFO Configuration:
# ---------------------+--------------------------
# Param                |           Value
# ---------------------+--------------------------
# tree                 |           False
# proj                 |           False
# partial              |           False
# mode                 |           train
# path                 | logs/diaparser.reddit.3.roberta-base
# device               |             0
# seed                 |             3
# threads              |            16
# batch_size           |           5000
# local_rank           |            -1
# verbose              |           True
# Parser               | <class 'diaparser.parsers.biaffine_dependency.BiaffineDependencyParser'>
# feat                 |           bert
# build                |           True
# punct                |           False
# max_len              |           None
# buckets              |            32
# ...

# %%
# !python -m diaparser.cmds.biaffine_dependency train  \
    --train ../UD_data/UD_English-GUMReddit/en_gumreddit-ud-train.conllu \
    --dev  ../UD_data/UD_English-GUMReddit/en_gumreddit-ud-dev.conllu \
    --test ../UD_data/UD_English-GUMReddit/en_gumreddit-ud-test.conllu \
    -b -d 0  \
    -p logs/diaparser.reddit.1.cardiffnlp-twitter-roberta-base  \
    -f bert  \
    --bert cardiffnlp/twitter-roberta-base  \
    -s 1
# Out:
# 2022-08-01 21:26:38 INFO Configuration:
# ---------------------+--------------------------
# Param                |           Value
# ---------------------+--------------------------
# tree                 |           False
# proj                 |           False
# partial              |           False
# mode                 |           train
# path                 | logs/diaparser.reddit.1.cardiffnlp-twitter-roberta-base
# device               |             0
# seed                 |             1
# threads              |            16
# batch_size           |           5000
# local_rank           |            -1
# verbose              |           True
# Parser               | <class 'diaparser.parsers.biaffine_dependency.BiaffineDependencyParser'>
# feat                 |           bert
# build                |           True
# punct                |           False
# max_len              |           None
# buckets              |            32
# ...

# %%
# !python -m diaparser.cmds.biaffine_dependency train  \
    --train ../UD_data/UD_English-GUMReddit/en_gumreddit-ud-train.conllu \
    --dev  ../UD_data/UD_English-GUMReddit/en_gumreddit-ud-dev.conllu \
    --test ../UD_data/UD_English-GUMReddit/en_gumreddit-ud-test.conllu \
    -b -d 0  \
    -p logs/diaparser.reddit.2.cardiffnlp-twitter-roberta-base  \
    -f bert  \
    --bert cardiffnlp/twitter-roberta-base  \
    -s 2
# Out:
# 2022-08-01 21:35:06 INFO Configuration:
# ---------------------+--------------------------
# Param                |           Value
# ---------------------+--------------------------
# tree                 |           False
# proj                 |           False
# partial              |           False
# mode                 |           train
# path                 | logs/diaparser.reddit.2.cardiffnlp-twitter-roberta-base
# device               |             0
# seed                 |             2
# threads              |            16
# batch_size           |           5000
# local_rank           |            -1
# verbose              |           True
# Parser               | <class 'diaparser.parsers.biaffine_dependency.BiaffineDependencyParser'>
# feat                 |           bert
# build                |           True
# punct                |           False
# max_len              |           None
# buckets              |            32
# ...

# %%
# !python -m diaparser.cmds.biaffine_dependency train  \
    --train ../UD_data/UD_English-GUMReddit/en_gumreddit-ud-train.conllu \
    --dev  ../UD_data/UD_English-GUMReddit/en_gumreddit-ud-dev.conllu \
    --test ../UD_data/UD_English-GUMReddit/en_gumreddit-ud-test.conllu \
    -b -d 0  \
    -p logs/diaparser.reddit.3.cardiffnlp-twitter-roberta-base  \
    -f bert  \
    --bert cardiffnlp/twitter-roberta-base  \
    -s 3
# Out:
# 2022-08-01 21:43:37 INFO Configuration:
# ---------------------+--------------------------
# Param                |           Value
# ---------------------+--------------------------
# tree                 |           False
# proj                 |           False
# partial              |           False
# mode                 |           train
# path                 | logs/diaparser.reddit.3.cardiffnlp-twitter-roberta-base
# device               |             0
# seed                 |             3
# threads              |            16
# batch_size           |           5000
# local_rank           |            -1
# verbose              |           True
# Parser               | <class 'diaparser.parsers.biaffine_dependency.BiaffineDependencyParser'>
# feat                 |           bert
# build                |           True
# punct                |           False
# max_len              |           None
# buckets              |            32
# ...

# %%
# !pip install torch==1.11.0+cu102 torchvision==0.12.0+cu102 torchaudio==0.11.0+cu102 -f https://download.pytorch.org/whl/cu102/torch_stable.html
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.pytorch.org/whl/cu102/torch_stable.html
# ...
#   Using cached https://download.pytorch.org/whl/cu102/torch-1.11.0%2Bcu102-cp37-cp37m-linux_x86_64.whl (750.6 MB)
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.7.0
#     Uninstalling torch-1.7.0:
#       Successfully uninstalled torch-1.7.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# allennlp 1.3.0 requires torch<1.8.0,>=1.6.0, but you have torch 1.11.0+cu102 which is incompatible.
# torchtext 0.13.0 requires torch==1.12.0, but you have torch 1.11.0+cu102 which is incompatible.
# ...

# %%
# %cd drive/MyDrive/childes_parsing/
# Out:
# /content/drive/MyDrive/childes_parsing

# %%
# !git clone https://github.com/UniversalDependencies/UD_English-EWT
# Out:
# Cloning into 'UD_English-EWT'...
# remote: Enumerating objects: 27349, done.
# remote: Counting objects: 100% (124/124), done.
# remote: Compressing objects: 100% (66/66), done.
# remote: Total 27349 (delta 81), reused 92 (delta 58), pack-reused 27225
# Receiving objects: 100% (27349/27349), 215.74 MiB | 15.09 MiB/s, done.
# Resolving deltas: 100% (24478/24478), done.
# Checking out files: 100% (1189/1189), done.

# %%
# !git clone https://github.com/UniversalDependencies/UD_English-GUMReddit
# Out:
# Cloning into 'UD_English-GUMReddit'...
# remote: Enumerating objects: 647, done.
# remote: Counting objects: 100% (105/105), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 647 (delta 81), reused 73 (delta 51), pack-reused 542
# Receiving objects: 100% (647/647), 2.75 MiB | 7.01 MiB/s, done.
# Resolving deltas: 100% (514/514), done.

# %%
# !mv UD_English-EWT UD_data/
# !mv UD_English-GUMReddit UD_data/

# %%
# !git clone https://github.com/machamp-nlp/machamp

# %%
# %cd machamp
# Out:
# /content/drive/MyDrive/childes_parsing/machamp/machamp
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# !pip3 install --user -r requirements.txt

# %%
# !python3 scripts/misc/cleanconl.py ../UD_data/*/*conllu
# Out:
# Cloning into 'ud-conversion-tools'...
# remote: Enumerating objects: 216, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 216 (delta 1), reused 4 (delta 0), pack-reused 208
# Receiving objects: 100% (216/216), 7.92 MiB | 7.89 MiB/s, done.
# Resolving deltas: 100% (93/93), done.
# cleaning ../UD_data/UD_English-EWT/en_ewt-ud-dev.conllu
# Not a tree after fused-form heuristics: i want to be able to use it in my car , out n about etc ... i guess like an iphone , but thats later on and , i know what they are so no suggestions on just goin out to buy one im talking about right now just for an ipod ??.
# cleaning ../UD_data/UD_English-EWT/en_ewt-ud-test.conllu
# cleaning ../UD_data/UD_English-EWT/en_ewt-ud-train.conllu
# cleaning ../UD_data/UD_English-GUMReddit/en_gumreddit-ud-dev.conllu
# cleaning ../UD_data/UD_English-GUMReddit/en_gumreddit-ud-test.conllu
# ...

# %%
# !python3 train.py --dataset_config ../configs/ewt.json --name machamp.ewt.1.bert-base-cased --parameters_config ../configs/params.bert-base-cased.json --seed 1 && cd ../
# !python3 train.py --dataset_config ../configs/ewt.json --name machamp.ewt.1.roberta-base --parameters_config ../configs/params.roberta-base.json --seed 1 && cd ../
# !python3 train.py --dataset_config ../configs/ewt.json --name machamp.ewt.1.cardiffnlp-twitter-roberta-base --parameters_config ../configs/params.cardiffnlp-twitter-roberta-base.json --seed 1 && cd ../
#!python3 train.py --dataset_config ../configs/ewt.json --name machamp.ewt.1.microsoft-deberta-v3-base --parameters_config ../configs/params.microsoft-deberta-v3-base.json --seed 1 && cd ../
#!python3 train.py --dataset_config ../configs/ewt.json --name machamp.ewt.1.studio-ousia-luke-base --parameters_config ../configs/params.studio-ousia-luke-base.json --seed 1 && cd ../

# %%
# !python3 train.py --dataset_config ../configs/ewt.json --name machamp.ewt.2.bert-base-cased --parameters_config ../configs/params.bert-base-cased.json --seed 2 && cd ../
# !python3 train.py --dataset_config ../configs/ewt.json --name machamp.ewt.2.roberta-base --parameters_config ../configs/params.roberta-base.json --seed 2 && cd ../
# !python3 train.py --dataset_config ../configs/ewt.json --name machamp.ewt.2.cardiffnlp-twitter-roberta-base --parameters_config ../configs/params.cardiffnlp-twitter-roberta-base.json --seed 2 && cd ../
#!python3 train.py --dataset_config ../configs/ewt.json --name machamp.ewt.2.microsoft-deberta-v3-base --parameters_config ../configs/params.microsoft-deberta-v3-base.json --seed 2 && cd ../
#!python3 train.py --dataset_config ../configs/ewt.json --name machamp.ewt.2.studio-ousia-luke-base --parameters_config ../configs/params.studio-ousia-luke-base.json --seed 2 && cd ../

# %%
# !python3 train.py --dataset_config ../configs/ewt.json --name machamp.ewt.3.bert-base-cased --parameters_config ../configs/params.bert-base-cased.json --seed 3 && cd ../
# !python3 train.py --dataset_config ../configs/ewt.json --name machamp.ewt.3.roberta-base --parameters_config ../configs/params.roberta-base.json --seed 3 && cd ../
# !python3 train.py --dataset_config ../configs/ewt.json --name machamp.ewt.3.cardiffnlp-twitter-roberta-base --parameters_config ../configs/params.cardiffnlp-twitter-roberta-base.json --seed 3 && cd ../
#!python3 train.py --dataset_config ../configs/ewt.json --name machamp.ewt.3.microsoft-deberta-v3-base --parameters_config ../configs/params.microsoft-deberta-v3-base.json --seed 3 && cd ../
#!python3 train.py --dataset_config ../configs/ewt.json --name machamp.ewt.3.studio-ousia-luke-base --parameters_config ../configs/params.studio-ousia-luke-base.json --seed 3 && cd ../

# %%
# !python3 train.py --dataset_config ../configs/reddit.json --name machamp.reddit.1.bert-base-cased --parameters_config ../configs/params.bert-base-cased.json --seed 1 && cd ../
# !python3 train.py --dataset_config ../configs/reddit.json --name machamp.reddit.1.roberta-base --parameters_config ../configs/params.roberta-base.json --seed 1 && cd ../
# !python3 train.py --dataset_config ../configs/reddit.json --name machamp.reddit.1.cardiffnlp-twitter-roberta-base --parameters_config ../configs/params.cardiffnlp-twitter-roberta-base.json --seed 1 && cd ../
#!python3 train.py --dataset_config ../configs/reddit.json --name machamp.reddit.1.microsoft-deberta-v3-base --parameters_config ../configs/params.microsoft-deberta-v3-base.json --seed 1 && cd ../
#!python3 train.py --dataset_config ../configs/reddit.json --name machamp.reddit.1.studio-ousia-luke-base --parameters_config ../configs/params.studio-ousia-luke-base.json --seed 1 && cd ../

# %%
# !python3 train.py --dataset_config ../configs/reddit.json --name machamp.reddit.2.bert-base-cased --parameters_config ../configs/params.bert-base-cased.json --seed 2 && cd ../
# !python3 train.py --dataset_config ../configs/reddit.json --name machamp.reddit.2.roberta-base --parameters_config ../configs/params.roberta-base.json --seed 2 && cd ../
# !python3 train.py --dataset_config ../configs/reddit.json --name machamp.reddit.2.cardiffnlp-twitter-roberta-base --parameters_config ../configs/params.cardiffnlp-twitter-roberta-base.json --seed 2 && cd ../
#!python3 train.py --dataset_config ../configs/reddit.json --name machamp.reddit.2.microsoft-deberta-v3-base --parameters_config ../configs/params.microsoft-deberta-v3-base.json --seed 2 && cd ../
#!python3 train.py --dataset_config ../configs/reddit.json --name machamp.reddit.2.studio-ousia-luke-base --parameters_config ../configs/params.studio-ousia-luke-base.json --seed 2 && cd ../

# %%
# !python3 train.py --dataset_config ../configs/reddit.json --name machamp.reddit.3.bert-base-cased --parameters_config ../configs/params.bert-base-cased.json --seed 3 && cd ../
# !python3 train.py --dataset_config ../configs/reddit.json --name machamp.reddit.3.roberta-base --parameters_config ../configs/params.roberta-base.json --seed 3 && cd ../
# !python3 train.py --dataset_config ../configs/reddit.json --name machamp.reddit.3.cardiffnlp-twitter-roberta-base --parameters_config ../configs/params.cardiffnlp-twitter-roberta-base.json --seed 3 && cd ../
#!python3 train.py --dataset_config ../configs/reddit.json --name machamp.reddit.3.microsoft-deberta-v3-base --parameters_config ../configs/params.microsoft-deberta-v3-base.json --seed 3 && cd ../
#!python3 train.py --dataset_config ../configs/reddit.json --name machamp.reddit.3.studio-ousia-luke-base --parameters_config ../configs/params.studio-ousia-luke-base.json --seed 3 && cd ../
