# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd drive/MyDrive/childes_parsing/
# Out:
# /content/drive/MyDrive/childes_parsing

# %%
# !pip install git+https://github.com/UppsalaNLP/uuparser
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/UppsalaNLP/uuparser to /tmp/pip-req-build-fzctnj5p
#   Running command git clone -q https://github.com/UppsalaNLP/uuparser /tmp/pip-req-build-fzctnj5p
# ...

# %%
# !mkdir uuparser

# %%
# !mkdir uuparser/logs/
# !mkdir uuparser/logs/1/
# !mkdir uuparser/logs/2/
# !mkdir uuparser/logs/3/

# %%
# !mkdir uuparser/predictions/
# !mkdir uuparser/predictions/1
# !mkdir uuparser/predictions/2
# !mkdir uuparser/predictions/3

# %%
# !uuparser --outdir uuparser/logs/1/ --datadir UD_data --include "en_ewt" --dynet-seed 1 --dynet-mem 10000
# Out:
# [uuparser] 2022-08-01T20:50:09 INFO: Creating language-specific output directory uuparser/en_ewt
# [uuparser] 2022-08-01T20:50:10 INFO: Working with a transition-based parser
# [uuparser] 2022-08-01T20:50:10 INFO: Reading UD_data/UD_English-EWT/en_ewt-ud-train.conllu
# [uuparser] 2022-08-01T20:50:15 INFO: Time: 4.9s
# [uuparser] 2022-08-01T20:50:15 INFO: Saving params to uuparser/en_ewt/params.pickle
# [dynet] random seed: 1
# [dynet] allocating memory: 10000MB
# tcmalloc: large alloc 2621440000 bytes == 0x2a48000 @  0x7ffa6e84eb6b 0x7ffa6e86e379 0x7ffa62553aed 0x7ffa624b60a6 0x7ffa624b6cf3 0x7ffa624d70fb 0x7ffa62520d0e 0x7ffa62bf217d 0x59af67 0x515655 0x549576 0x604173 0x62a809 0x5939af 0x516337 0x549576 0x593fce 0x548ae9 0x51566f 0x593dd7 0x511e2c 0x593dd7 0x5118f8 0x593dd7 0x5118f8 0x4bc98a 0x59582d 0x595c46 0x504d68 0x5142e7 0x549576
# ...

# %%
# !uuparser --predict --modeldir uuparser/logs/1/ --outdir uuparser/predictions/1/ --datadir UD_data --include "en_ewt"
# Out:
# [uuparser] 2022-08-02T06:37:08 INFO: Warning: language-specific subdirectory uuparser/logs/1/en_ewt already exists, contents may be overwritten
# [uuparser] 2022-08-02T06:37:08 INFO: Working with a transition-based parser
# [uuparser] 2022-08-02T06:37:08 INFO: Reading params from uuparser/logs/1/en_ewt/params.pickle
# [dynet] random seed: 942974205
# [dynet] allocating memory: 512MB
# [dynet] memory allocation done.
# [uuparser] 2022-08-02T06:37:09 INFO: Loading model from uuparser/logs/1/en_ewt/barchybrid.model
# [uuparser] 2022-08-02T06:37:10 INFO: Reading UD_data/UD_English-EWT/en_ewt-ud-test.conllu
# [uuparser] 2022-08-02T06:37:11 INFO: Time: 0.88s
# [uuparser] 2022-08-02T06:37:11 INFO: Reading UD_data/UD_English-EWT/en_ewt-ud-test.conllu
# Parsing: 0sentences [00:00, ?sentences/s]The dy.parameter(...) call is now DEPRECATED.
#         There is no longer need to explicitly add parameters to the computation graph.
#         Any used parameter will be added automatically.
# ...

# %%
# !uuparser --outdir uuparser/logs/2/ --datadir UD_data --include "en_ewt" --dynet-seed 2 --dynet-mem 10000

# %%
# !uuparser --predict --modeldir uuparser/logs/2/ --outdir uuparser/predictions/2/ --datadir UD_data --include "en_ewt"
# Out:
# [uuparser] 2022-08-02T19:31:59 INFO: Creating language-specific output directory uuparser/predictions/2/en_ewt
# [uuparser] 2022-08-02T19:32:01 INFO: Working with a transition-based parser
# [uuparser] 2022-08-02T19:32:01 INFO: Reading params from uuparser/logs/2/en_ewt/params.pickle
# [dynet] random seed: 1699935732
# [dynet] allocating memory: 512MB
# [dynet] memory allocation done.
# [uuparser] 2022-08-02T19:32:01 INFO: Loading model from uuparser/logs/2/en_ewt/barchybrid.model
# [uuparser] 2022-08-02T19:32:04 INFO: Reading UD_data/UD_English-EWT/en_ewt-ud-test.conllu
# [uuparser] 2022-08-02T19:32:04 INFO: Time: 0.41s
# [uuparser] 2022-08-02T19:32:04 INFO: Reading UD_data/UD_English-EWT/en_ewt-ud-test.conllu
# Parsing: 0sentences [00:00, ?sentences/s]The dy.parameter(...) call is now DEPRECATED.
#         There is no longer need to explicitly add parameters to the computation graph.
#         Any used parameter will be added automatically.
# ...

# %%
# !uuparser --outdir uuparser/logs/3/ --datadir UD_data --include "en_ewt" --dynet-seed 3 --dynet-mem 10000
# Out:
# [uuparser] 2022-08-02T06:42:27 INFO: Creating language-specific output directory uuparser/en_ewt
# [uuparser] 2022-08-02T06:42:27 INFO: Working with a transition-based parser
# [uuparser] 2022-08-02T06:42:27 INFO: Reading UD_data/UD_English-EWT/en_ewt-ud-train.conllu
# [uuparser] 2022-08-02T06:42:31 INFO: Time: 4.6s
# [uuparser] 2022-08-02T06:42:31 INFO: Saving params to uuparser/en_ewt/params.pickle
# [dynet] random seed: 3
# [dynet] allocating memory: 10000MB
# tcmalloc: large alloc 2621440000 bytes == 0x347e000 @  0x7fc966ea0b6b 0x7fc966ec0379 0x7fc95aba5aed 0x7fc95ab080a6 0x7fc95ab08cf3 0x7fc95ab290fb 0x7fc95ab72d0e 0x7fc95b24417d 0x59af67 0x515655 0x549576 0x604173 0x62a809 0x5939af 0x516337 0x549576 0x593fce 0x548ae9 0x51566f 0x593dd7 0x511e2c 0x593dd7 0x5118f8 0x593dd7 0x5118f8 0x4bc98a 0x59582d 0x595c46 0x504d68 0x5142e7 0x549576
# ...

# %%
# !uuparser --predict --modeldir uuparser/logs/3/ --outdir uuparser/predictions/3/ --datadir UD_data --include "en_ewt"
# Out:
# [uuparser] 2022-08-02T19:28:28 INFO: Warning: language-specific subdirectory uuparser/predictions/3/en_ewt already exists, contents may be overwritten
# [uuparser] 2022-08-02T19:28:28 INFO: Working with a transition-based parser
# [uuparser] 2022-08-02T19:28:28 INFO: Reading params from uuparser/logs/3/en_ewt/params.pickle
# [dynet] random seed: 2679074717
# [dynet] allocating memory: 512MB
# [dynet] memory allocation done.
# [uuparser] 2022-08-02T19:28:28 INFO: Loading model from uuparser/logs/3/en_ewt/barchybrid.model
# [uuparser] 2022-08-02T19:28:30 INFO: Reading UD_data/UD_English-EWT/en_ewt-ud-test.conllu
# [uuparser] 2022-08-02T19:28:30 INFO: Time: 0.39s
# [uuparser] 2022-08-02T19:28:30 INFO: Reading UD_data/UD_English-EWT/en_ewt-ud-test.conllu
# Parsing: 0sentences [00:00, ?sentences/s]The dy.parameter(...) call is now DEPRECATED.
#         There is no longer need to explicitly add parameters to the computation graph.
#         Any used parameter will be added automatically.
# ...

# %%
# !uuparser --outdir uuparser --datadir UD_data --include "en_gumreddit" --dynet-seed 1 --dynet-mem 10000

# %%
# !uuparser --outdir uuparser --datadir UD_data --include "en_gumreddit" --dynet-seed 2 --dynet-mem 10000

# %%
# !uuparser --outdir uuparser --datadir UD_data --include "en_gumreddit" --dynet-seed 3 --dynet-mem 10000
